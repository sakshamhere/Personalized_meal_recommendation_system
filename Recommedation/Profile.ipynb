# %% [markdown]
# ### Profile

# %%
import pandas as pd 
import numpy as np
import warnings
import time
import seaborn as sns
import matplotlib.pyplot as plt
import random
import nltk
from nltk.corpus import stopwords

warnings.filterwarnings('ignore')

# %%
class Profile:
    
    df = pd.read_csv('dataset.csv').drop('Unnamed: 0',axis=1) # static variable
    
    def __init__(self,diet,disease,Nutrient,food_type,favorite_food):
        self.diet = diet
        self.disease = disease
        self.nutrient = Nutrient
        self.type = food_type
        self.like = favorite_food
        self.df2 = pd.DataFrame(columns=list(Profile.df.columns))
        self.df3 = pd.DataFrame(columns=list(Profile.df.columns))
        self.df4 = pd.DataFrame(columns=list(Profile.df.columns))
        self.df5 = pd.DataFrame(columns=list(Profile.df.columns))
        self.df6 = pd.DataFrame(columns=list(Profile.df.columns))
        
    def removestop(self,tokens):
        stop = set(stopwords.words('english'))
        file = open('stopwords.txt','r')
        l = list(file.read().split())
        stop = list(stop) +l
        l = [token for token in tokens if token not in stop]
        return l
            
    def inputs(self,diet,disease,Nutrient,food_type,favorite_food):
        
        if Nutrient:
            self.df2 = Profile.df[Profile.df.Nutrient.isin(Nutrient)]
            self.df2 = self.df2.reset_index()
       
        if food_type:
            self.df2 = self.df2[self.df2.Veg_Non.isin(food_type)]
            self.df2 = self.df2.reset_index()
      
        if diet:
            for i in range(self.df2.shape[0]):
                l = str(self.df2.loc[i,'Diet']).split()
                
                for d in diet:
                    if d in l:
                        self.df4=self.df4.append(self.df2.loc[i])
 
        if disease:
            for i in range(self.df2.shape[0]):
                l = str(self.df2.loc[i,'Disease']).split()
                for d in disease:
                    if d in l:
                        self.df5=self.df5.append(self.df2.loc[i])

        if favorite_food:
            f = self.removestop(favorite_food.split())
            for i in range(Profile.df.shape[0]):
                n = [j.lower() for j in str(Profile.df.loc[i,'Name']).split()]
                for j in n:
                    for k in f:
                        if k==j:
                            self.df6=self.df6.append(Profile.df.loc[i])
            for i in range(Profile.df.shape[0]):
                n = [j.lower() for j in str(Profile.df.loc[i,'description']).split()]
                for j in n:
                    for k in f:
                        if k==j:
                            self.df6=self.df6.append(df.loc[i])
            for i in range(Profile.df.shape[0]):
                n = [j.lower() for j in str(Profile.df.loc[i,'catagory']).split()]
                for j in n:
                    for k in f:
                        if k==j:
                            self.df6=self.df6.append(Profile.df.loc[i])
            
        return self.df2,self.df3,self.df4,self.df5,self.df6
    
    def get_profile(self):
        df2,df3,df4,df5,df6 = self.inputs(self.diet,self.disease,self.nutrient,self.type,self.like)
        
        df_merge = pd.concat([df2,df3,df4,df5,df6],axis=0).drop_duplicates(subset='Name')
        df_merge = df_merge.filter(['Name','Nutrient','Veg_Non','Price','Review','description'])
        print(df_merge.shape)
        
        return df_merge

# %%
# multiple inputs by radio button
ob = Profile(['high_protien_diet','gluten_free_diet'],['diabeties','anemia'],
             ['calcium','protien'],['non-veg','veg'],'i like burger and sandwich')

profile = ob.get_profile()
profile
# Out:
# (113, 6)
#                                               Name   Nutrient  Veg_Non Price  \
# 0       japanese curry arancini with  barley salsa    calcium      veg   310
# 1                             cream of almond soup    calcium      veg   335
# 2     lemon honey glazed sous vide corn on the cob    protien  non-veg   405
# 3                                 gucchi mussallam    calcium      veg   580
# 4          baked namakpara with roasted almond dip    calcium      veg   430
# 5                grilled almond barfi (sugar free)    calcium      veg   355
# 6                                      apple rabdi    calcium      veg   440
# 7                       green lentil dessert fudge    calcium      veg   520
# 8                               cashew nut cookies    protien      veg   580
# 9                                    almond pearls    protien      veg   345
# 10                              baked almond kofta    calcium      veg   530
# 11                       almond and amaranth ladoo    calcium      veg   330
# 12                    sweet potato and quinoa bowl    protien      veg   460
# 13                                    oats khichdi    protien      veg   295
# 14        almond and chicken momos (without shell)    calcium  non-veg   205
# 15                               christmas cookies    protien      veg   325
# 18                          sous-vide salmon tikka    calcium  non-veg   305
# 19                                   tiny vada pao    calcium      veg   295
# 20                                      filo pizza    calcium      veg   680
# 23               caramelized sesame smoked almonds    calcium      veg   320
# 24                                beyond the ozone    calcium      veg   530
# 25                                 kimami sewaiyan    calcium      veg   685
# 26                      badam aur gulkand ki kulfi    calcium      veg   210
# 27                                 tricolour pasta    calcium      veg   655
# 28               clotted cottage cheese croquettes    calcium      veg   490
# 31                                   guava chutney    protien      veg   300
# 32                                  thandai phirni    calcium      veg   385
# 33                    holi special ice tea thandai    calcium      veg   585
# 34                                      cappuccino    calcium      veg   275
# 35                                     methi murgh    calcium  non-veg   520
# ...                                            ...        ...      ...   ...
# 128                arbi kofta with mint yogurt dip    calcium      veg   250
# 129                                  aloo ki kadhi    protien      veg   575
# 130                         singhare atte ka halwa    calcium      veg   395
# 132                                 vratwali kheer    calcium      veg   205
# 133                           mango and mint kheer    calcium      veg   655
# 134                             sookhe kale channe    calcium      veg   395
# 135                      red velvet banana pudding    calcium      veg   370
# 145                        jalapeno cheese fingers    calcium      veg   400
# 146                 californian breakfast benedict    protien      veg   220
# 160                      date and pistachio muffin    protien      veg   210
# 165                    french onion grilled cheese    calcium      veg   240
# 166                          pasta in cheese sauce    calcium      veg   660
# 167                                      aloo gobi    protien      veg   485
# 168                              aloo shimla mirch    protien      veg   605
# 169                           chicken tikka masala    calcium  non-veg   685
# 170                                          kadhi    calcium      veg   300
# 171                                  makki di roti    protien      veg   610
# 172                                    shahi tukra    calcium      veg   675
# 173                                         dabeli    protien      veg   255
# 174                                      dahi vada    calcium      veg   500
# 175                                      dum aaloo    protien      veg   380
# 176                                      pav bhaji    protien      veg   665
# 177                                   rasya muthia    calcium      veg   615
# 178                                          litti    protien      veg   550
# 179                                 baingan bharta    calcium      veg   465
# 181                                        khandvi    calcium      veg   510
# 182                                      shrikhand    calcium      veg   685
# 183                                          vadai    protien      veg   665
# 397                egg and cheddar cheese sandwich  vitamin_a  non-veg   530
# 1101                                      sandwich      fiber      veg   390
#
#      Review                                        description
# 0         1  japanese curry, sticky rice, cheese inside ric...
# 1         3  vegetable stock, skimmed milk, toasted almonds...
# 2         4  young corn on the cob, honey, lemon juice, gar...
# 3         2  morels, khoya pindi, cheese , saffron, cashew ...
# 4         4  almonds (crushed), tomato, garlic cloves, basi...
# 5         3     khoya, sweetener (optional), almonds (crushed)
# 6         1  apples, milk, sugar, green cardamoms, almonds ...
# 7         4  whole moong beans, cow ghee, raisins, whole mi...
# 8         1  cashew paste, ghee, khaand (a sweetening agent...
# 9         4  toasted almonds, blueberries, oats, corn flake...
# 10        2  potato (boiled), nutmeg, milk, almonds (crushe...
# 11        3  popped amaranth seeds, jaggery, almonds (slive...
# 12        4  स्वीट पौटेटो क्यूब्स, नारियल, प्याज, क्निोआ (प...
# 13        3  क्विक कुकिंग ओट्स, मूंगदाल, जीरा, हल्दी पाउडर,...
# 14        2  chicken mince, garlic, carrots, spring onion, ...
# 15        2  butter, castor sugar, eggs, refined flour, soa...
# 18        5  norwegian salmon, black garlic pickle, butter,...
# 19        2  potatoes (boiled and mashed), garlic, ginger, ...
# 20        1  filo pastry, himalayan salt, black pepper, sal...
# 23        1  साबुत बादाम, सफेद और काले तिल, चीनी, रोजमेरी, ...
# 24        2  for vanilla sponge:, all purpose flour, cornst...
# 25        4  semiya, khoya, sugar, milk, water, ghee (as ne...
# 26        3  almonds whole, gulab ki patti, full fat milk, ...
# 27        2  penne, fresh broccoli, carrot, green onions, b...
# 28        1  black pepper, black salt, bread crumb, corn fl...
# 31        4  अमरूद , नमक, नींबू का रस, हरी मिर्च, अदरक, लाल...
# 32        1  milk, rice (soaked in water for at least 3 hou...
# 33        1  ground white pepper (kali mirch), assam tea ba...
# 34        2  दूध, दालचीनी स्टिक, स्ट्रांग कॉफी, चीनी , दालच...
# 35        2  chicken breast (boneless, cut into 2 inch cube...
# ...     ...                                                ...
# 128       1  arbi/colocasia roots, water chestnut flour (ku...
# 129       5  potatoes (peeled& mashed smooth), rock salt, c...
# 130       5  singhare ka atta, sugar, water, ghee, green ca...
# 132       5  milk, samwat / parsai ke chawal (washed), suga...
# 133       2  milk, basmati rice, powdered sugar / sugar sub...
# 134       2  काले चने, काला नमक और साधारण नमक, भूना जीरा (प...
# 135       3  one can of sweetened condensed milk, ice cold ...
# 145       3  yellow cornmeal, sugar, baking soda, salt, but...
# 146       4  brioche loaf, avocado paste, eggs, tomato, spi...
# 160       5  ghee or white butter, khaand (a sweetening age...
# 165       1     ब्राउचे स्लाइस ब्रेड, प्याज, तेल , एमैंटल चीज़
# 166       2  दूध, मैदा, मक्खन, कालीमिर्च पाउडर, जायफल, चीज़...
# 167       4  potatoes sautéed with garam masala, turmeric, ...
# 168       3  ith potatoes sautéed with cumin seeds, onions,...
# 169       1        d in a yogurt tomato sauce. creamy texture.
# 170       2                  yogurt with gramflour fried balls
# 171       1  mustard) leaves, with heavily buttered roti ma...
# 172       3  a rich sauce of thickened milk, garnished with...
# 173       1  xing boiled potatoes with a special dabeli mas...
# 174       5             ls in a yogurt sauce. lentils, yogurt.
# 175       2  oes deep fry, yogurt, coriander powder, ginger...
# 176       3        nion, capsicum, peas, cauliflower potatoes.
# 177       4                               ogurt dumpling soup.
# 178       2  nd sattu baked in oven and served with mashed ...
# 179       4  sh bearing a resemblance to baba ganoush, it i...
# 181       5  m used for a type of snacks in gujarati cuisin...
# 182       4  e of strained yogurt.[65] it is one of the mai...
# 183       2  -type snack from south india,[66] vadai is a t...
# 397       3        egg, salt, pepper, ham slices, basil leaves
# 1101      4  isting of two or more slices of bread with one...
#
# [113 rows x 6 columns]
