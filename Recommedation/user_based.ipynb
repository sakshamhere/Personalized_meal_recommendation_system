# %% [markdown]
# ### User based Recommendation (Collaborative filtering)
#
# -  if user A  and user B share similar profile then meal liked by User B but  not rated by A are recommended to A
# - User-based: measure the similarity between target users and other users
# - Collaborative filtering systems make recommendations based on historic users’ preference for items (clicked, watched, purchased, liked, rated, etc.).

# %% [markdown]
# ### Algorithm - K_Nearest-neighbor

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.neighbors import NearestNeighbors

df_profile = pd.read_csv('user_Profiles.csv')
df_activity = pd.read_csv('user_activity.csv')
df_profile.head(3)
# Out:
#   User_Id  Veg_Non       Nutrient  \
# 0  User_1  non-veg       chloride
# 1  User_2      veg  carbohydrates
# 2  User_3  non-veg           iron
#
#                                            Disease  \
# 0   rickets goitre pregnancy kidney_disease anemia
# 1                                 diabeties goitre
# 2   rickets goitre pregnancy kidney_disease anemia
#
#                                                 Diet
# 0   hormone_diet low_carb_diet high_protien_diet ...
# 1   high_fiber_diet high_protien_diet low_fat_die...
# 2   high_fiber_diet hormone_diet low_carb_diet hi...

# %%
df_activity.head(3)
# Out:
#    User_Id                  Name catagory  \
# 0  User_98   summer squash salad    salad
# 1  User_18  chicken minced salad    salad
# 2  User_96  sweet chilli almonds   chilli
#
#                                          description  Veg_Non  Review  \
# 0  white balsamic vinegar, lemon juice, lemon rin...      veg      10
# 1  olive oil, chicken mince, garlic (minced), oni...  non-veg      10
# 2  almonds whole, egg white, curry leaves, salt, ...      veg       9
#
#     Nutrient                                            Disease  \
# 0      fiber              diabeties hypertension obesity goitre
# 1      fiber   rickets pregnancy goitre obesity kidney_disea...
# 2  vitamin_a   scurvy pregnancy goitre heart_disease kidney_...
#
#                                                 Diet  Price
# 0   high_fiber_diet high_protien_diet dash_diet k...    320
# 1   high_fiber_diet hormone_diet low_carb_diet hi...    520
# 2   Mediterranean_diet high_fiber_diet high_proti...    465

# %%
class Recommender:
    
    def __init__(self):
        self.df = pd.read_csv('user_Profiles.csv')
        self.activity = pd.read_csv('user_activity.csv')
    
    def get_features(self):
        #getting dummies of dataset
        nutrient_dummies = self.df.Nutrient.str.get_dummies()
        disease_dummies = self.df.Disease.str.get_dummies(sep=' ')
        diet_dummies = self.df.Diet.str.get_dummies(sep=' ')
        feature_df = pd.concat([nutrient_dummies,disease_dummies,diet_dummies],axis=1)
     
        return feature_df
    
    def k_neighbor(self,inputs):
        
        feature_df = self.get_features()
        
        #initializing model with k=20 neighbors
        model = NearestNeighbors(n_neighbors=6,algorithm='ball_tree')
        
        # fitting model with dataset features
        model.fit(feature_df)
        
        df_results = pd.DataFrame(columns=list(self.df.columns))
        
      
        # getting distance and indices for k nearest neighbor
        distnaces , indices = model.kneighbors(inputs)

        for i in list(indices):
            df_results = df_results.append(self.df.loc[i])
                
#         df_results = df_result
        
        df_results = df_results.reset_index(drop=True)
        return df_results
    
    def user_based(self,user_profile,user_id):
        
        data = self.get_features()
        total_features = data.columns
        d = dict()
        for i in total_features:
            d[i]= 0
        for i in user_profile:
            d[i] = 1
        final_input = list(d.values())
        
        similar_users = self.k_neighbor([final_input])
        users = list(similar_users.User_Id)
        results = self.activity[self.activity.User_Id.isin(users)] #taking acitivies
        results = results[results['User_Id']!=user_id] # selecting those which are not reviewed by user
        results = results.filter(['Name','Nutrient','Veg_Non','Price','Review','Diet','Disease','description'])

        results = results.drop_duplicates(subset=['Name'])
        results = results.reset_index(drop=True)
        return results

# %% [markdown]
# ### for Example user A =='User_71' Profile says :

# %%
profile_A = ['calcium','iron','diabeties','gluten_free_diet']
user_id = 'User_71' # asumming for example

# %% [markdown]
# - finding similar users

# %%
ob = Recommender()
data = ob.get_features()
total_features = data.columns
d = dict()
for i in total_features:
    d[i]= 0
for i in profile_A:
    d[i] = 1

final_input = list(d.values())
similar_users = ob.k_neighbor([final_input]) # pass 2d array []
similar_users
# Out:
#    User_Id  Veg_Non   Nutrient        Disease  \
# 0  User_66      veg    protien   hypertension
# 1  User_32      veg       iron   hypertension
# 2  User_16      veg       iron   hypertension
# 3  User_46      veg    protien   hypertension
# 4   User_6  non-veg       iron         goitre
# 5   User_8      veg  vitamin_e   hypertension
#
#                                                 Diet
# 0                                   gluten_free_diet
# 1   high_fiber_diet vegan_diet gluten_free_diet l...
# 2   high_fiber_diet vegan_diet gluten_free_diet l...
# 3       dash_diet gluten_free_diet high_protien_diet
# 4            high_fiber_diet vegan_diet low_fat_diet
# 5       dash_diet gluten_free_diet high_protien_diet

# %% [markdown]
# - recommending meals that are new to user A and reviwed by above users

# %%
recommendations = ob.user_based(profile_A,user_id) 
recommendations
# Out:
#                                                  Name       Nutrient  Veg_Non  \
# 0                           almond and cranberry poha           iron      veg
# 1                                       almond pearls        protien      veg
# 2                                        oats khichdi        protien      veg
# 3                            andhra pan fried pomfret           iron      veg
# 4                                christmas tree pizza       chloride      veg
# 5                chicken parmigiana with tomato sauce      vitamin_c  non-veg
# 6                                       chicken potli           iron  non-veg
# 7                                zucchini methi pulao       chloride      veg
# 8                                    prawn fried rice  carbohydrates      veg
# 9                                    chocolate samosa      magnesium      veg
# 10                                    lamb barley pot           iron  non-veg
# 11  amaranthus granola with lemon yogurt, berries ...        calcium      veg
# 12                               vegetable manchurian      vitamin_a      veg
# 13                            ragi oats ladoo (laddu)      vitamin_e      veg
# 14              lamb and chargrilled bell pepper soup         sodium  non-veg
# 15       lemon honey glazed sous vide corn on the cob        protien  non-veg
# 16                                 carrot ginger soup         sodium      veg
# 17                 watermelon and strawberry smoothie      magnesium      veg
# 18                                   fruit cube salad          fiber      veg
#
#     Price  Review                                               Diet  \
# 0     425       9   high_fiber_diet vegan_diet gluten_free_diet l...
# 1     380       5                                   gluten_free_diet
# 2     200       4       dash_diet gluten_free_diet high_protien_diet
# 3     390       1   high_fiber_diet hormone_diet low_fat_diet veg...
# 4     250       7                         high_fiber_diet vegan_diet
# 5     475      10   hormone_diet low_carb_diet high_protien_diet ...
# 6     340      10   high_fiber_diet hormone_diet low_carb_diet hi...
# 7     270       7                                     ketogenic_diet
# 8     515       5   hormone_diet high_protien_diet dash_diet keto...
# 9     460       8   high_fiber_diet ketogenic_diet high_protien_diet
# 10    635       9            high_fiber_diet vegan_diet low_fat_diet
# 11    305       7   Mediterranean_diet high_protien_diet dash_die...
# 12    300      10   high_fiber_diet high_protien_diet low_fat_die...
# 13    455       2       dash_diet gluten_free_diet high_protien_diet
# 14    360       4                                      alkaline_diet
# 15    320      10   dash_diet gluten_free_diet high_protien_diet ...
# 16    675       6                      high_fiber_diet alkaline_diet
# 17    310       1                  high_fiber_diet high_protien_diet
# 18    470       7   high_fiber_diet high_protien_diet ketogenic_d...
#
#                                               Disease  \
# 0                                        hypertension
# 1                                        hypertension
# 2                                        hypertension
# 3                                              cancer
# 4                                              goitre
# 5      rickets goitre pregnancy kidney_disease anemia
# 6      rickets goitre pregnancy kidney_disease anemia
# 7                                    diabeties goitre
# 8                     diabeties cancer obesity anemia
# 9                          heart_disease hypertension
# 10                                             goitre
# 11   scurvy pregnancy goitre heart_disease obesity...
# 12        kidney_disease heart_disease scurvy obesity
# 13                                       hypertension
# 14     scurvy goitre pregnancy obesity kidney_disease
# 15                            diabeties scurvy goitre
# 16                                            obesity
# 17                                             scurvy
# 18   diabeties scurvy pregnancy goitre heart_disea...
#
#                                           description
# 0   almond flakes, onion, poha, cranberries (froze...
# 1   toasted almonds, blueberries, oats, corn flake...
# 2   क्विक कुकिंग ओट्स, मूंगदाल, जीरा, हल्दी पाउडर,...
# 3   white pomfret fish, sunflower refined ooil, re...
# 4   pizza dough (2 boules), red pepper, red onion,...
# 5   for chicken parmigiana:, chicken breast, egg w...
# 6   chicken, onion, green chilli, garlic, ginger, ...
# 7   zucchini, basmati rice, fenugreek (methi), cla...
# 8   तेल, बैकन, प्रॉन्स, चिकन, गाजर, लहसुन की कलिया...
# 9   refined flour, desi ghee, black cardamom seeds...
# 10  pot barley, onions, worcestershire sauce, chil...
# 11  popped amaranthus (cholai), oats, almonds, cin...
# 12  mixed vegetables - chopped fine or grated, egg...
# 13  ragi flour, oats flour, dates (ripe), milk, ho...
# 14  lamb bones (preferably shank and shoulder), on...
# 15  young corn on the cob, honey, lemon juice, gar...
# 16  गाजर, जैतून का तेल, नमक, वेजिटेबल स्टॉक, अदरक ...
# 17  fresh strawberries, honey, low fat yogurt, wat...
# 18  watermelon, cantaloupe, kiwifruiit, pineapple,...
