# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.neighbors import NearestNeighbors

df = pd.read_csv('dataset.csv')

# %% [markdown]
# ### Recommendation by K nearest neighbor 'KNN'  (Content - based filtering)

# %%
class Recommender:
    
    def __init__(self):
        self.df = pd.read_csv('dataset.csv')
    
    def get_features(self):
        #getting dummies of dataset
        nutrient_dummies = self.df.Nutrient.str.get_dummies()
        disease_dummies = self.df.Disease.str.get_dummies(sep=' ')
        diet_dummies = self.df.Diet.str.get_dummies(sep=' ')
        feature_df = pd.concat([nutrient_dummies,disease_dummies,diet_dummies],axis=1)
     
        return feature_df
    
    def k_neighbor(self,inputs):
        
        feature_df = self.get_features()
        
        #initializing model with k=20 neighbors
        model = NearestNeighbors(n_neighbors=40,algorithm='ball_tree')
        
        # fitting model with dataset features
        model.fit(feature_df)
        
        df_results = pd.DataFrame(columns=list(self.df.columns))
        
      
        # getting distance and indices for k nearest neighbor
        distnaces , indices = model.kneighbors(inputs)

        for i in list(indices):
            df_results = df_results.append(self.df.loc[i])
                
        df_results = df_results.filter(['Name','Nutrient','Veg_Non','Price','Review','Diet','Disease','description'])
        df_results = df_results.drop_duplicates(subset=['Name'])
        df_results = df_results.reset_index(drop=True)
        return df_results

# %% [markdown]
# ### sample data on which we recommed

# %%
ob = Recommender()
data = ob.get_features()

total_features = data.columns
d = dict()
for i in total_features:
    d[i]= 0
print(d)
# Out:
# {'calcium': 0, 'carbohydrates': 0, 'chloride': 0, 'fiber': 0, 'iodine': 0, 'iron': 0, 'magnesium': 0, 'manganese': 0, 'phosphorus': 0, 'potassium': 0, 'protien': 0, 'selenium': 0, 'sodium': 0, 'vitamin_a': 0, 'vitamin_c': 0, 'vitamin_d': 0, 'vitamin_e': 0, 'anemia': 0, 'cancer': 0, 'diabeties': 0, 'eye_disease': 0, 'goitre': 0, 'heart_disease': 0, 'hypertension': 0, 'kidney_disease': 0, 'obesity': 0, 'pregnancy': 0, 'rickets': 0, 'scurvy': 0, 'Mediterranean_diet': 0, 'alkaline_diet': 0, 'dash_diet': 0, 'gluten_free_diet': 0, 'high_fiber_diet': 0, 'high_protien_diet': 0, 'hormone_diet': 0, 'ketogenic_diet': 0, 'low_carb_diet': 0, 'low_fat_diet': 0, 'low_sodium_diet': 0, 'omni_diet': 0, 'paleo_diet': 0, 'type_a_diet': 0, 'type_o_diet': 0, 'vegan_diet': 0}

# %% [markdown]
# - convert data into 0 and 1 form by the help of dictionary

# %%
sample_input = ['high_protien_diet','gluten_free_diet','diabeties','anemia','calcium','protien']

for i in sample_input:
    
    d[i] = 1

final_input = list(d.values())

# %% [markdown]
# ### Results

# %%
results = ob.k_neighbor([final_input]) # pass 2d array []
results
# Out:
#                                             Name       Nutrient  Veg_Non  \
# 0                                     corn pulao        protien      veg
# 1                                   oats khichdi        protien      veg
# 2                               veg summer rolls  carbohydrates      veg
# 3                                  almond pearls        protien      veg
# 4                      oats &amp; shallots pulao        protien      veg
# 5                                    apple kheer      vitamin_e      veg
# 6   lemon honey glazed sous vide corn on the cob        protien  non-veg
# 7                                     rice kheer        calcium      veg
# 8         cajun spiced turkey wrapped with bacon      vitamin_c  non-veg
# 9              roast turkey with cranberry sauce       chloride  non-veg
# 10                californian breakfast benedict        protien      veg
# 11                     almond and amaranth ladoo        calcium      veg
# 12                                   apple rabdi        calcium      veg
# 13                         cinnamon star cookies        protien      veg
# 14                       ragi oats ladoo (laddu)      vitamin_e      veg
# 15                           puffed rice squares  carbohydrates      veg
# 16                    gluten-free christmas cake      vitamin_a      veg
# 17                            cashew nut cookies        protien      veg
# 18                 shrimp &amp; cilantro ceviche      vitamin_a      veg
# 19                   corn &amp; jalapeno poppers           iron      veg
# 20                                          rice  carbohydrates      veg
# 21                buldak (hot and spicy chicken)      magnesium  non-veg
# 22            watermelon and strawberry smoothie      magnesium      veg
# 23                          zucchini methi pulao       chloride      veg
#
#    Price Review                                               Diet  \
# 0    430      4    gluten_free_diet low_fat_diet high_protien_diet
# 1    580      2       gluten_free_diet dash_diet high_protien_diet
# 2    395      1                                  high_protien_diet
# 3    275      5                                   gluten_free_diet
# 4    370      5       gluten_free_diet dash_diet high_protien_diet
# 5    345      1                                  high_protien_diet
# 6    225      4   dash_diet gluten_free_diet low_fat_diet high_...
# 7    565      2   vegan_diet low_fat_diet high_protien_diet ket...
# 8    280      1                                  high_protien_diet
# 9    595      4                                  high_protien_diet
# 10   405      4                                  high_protien_diet
# 11   500      2   vegan_diet low_fat_diet high_protien_diet ket...
# 12   325      4   ketogenic_diet vegan_diet low_fat_diet high_p...
# 13   615      4                                     ketogenic_diet
# 14   600      2       gluten_free_diet dash_diet high_protien_diet
# 15   220      5   ketogenic_diet vegan_diet dash_diet high_prot...
# 16   340      1                                  high_protien_diet
# 17   300      5   ketogenic_diet vegan_diet dash_diet high_prot...
# 18   365      1                                     ketogenic_diet
# 19   495      2   high_fiber_diet vegan_diet low_fat_diet high_...
# 20   305      2   ketogenic_diet vegan_diet dash_diet high_prot...
# 21   580      3                  high_fiber_diet high_protien_diet
# 22   570      3                  high_fiber_diet high_protien_diet
# 23   400      1                                     ketogenic_diet
#
#                            Disease  \
# 0                 goitre diabeties
# 1                     hypertension
# 2                        diabeties
# 3                     hypertension
# 4                     hypertension
# 5                diabeties obesity
# 6          goitre diabeties scurvy
# 7         diabeties obesity anemia
# 8                           cancer
# 9                           goitre
# 10    rickets obesity hypertension
# 11                    hypertension
# 12               diabeties obesity
# 13   cancer diabeties hypertension
# 14                    hypertension
# 15        diabeties obesity anemia
# 16           kidney_disease goitre
# 17                    hypertension
# 18                   goitre anemia
# 19                goitre diabeties
# 20        diabeties obesity anemia
# 21                         obesity
# 22                          scurvy
# 23                goitre diabeties
#
#                                           description
# 0   बासमती चावल, अमेरिकन कॉर्न के दाने, जैतून का त...
# 1   क्विक कुकिंग ओट्स, मूंगदाल, जीरा, हल्दी पाउडर,...
# 2   rice paper sheets, iceberg lettuce, carrot, be...
# 3   toasted almonds, blueberries, oats, corn flake...
# 4   चावल, हरा धनिया, हरी मिर्च, प्याज , दालचीनी, इ...
# 5   apples, basmati rice, nuscovado sugar (you can...
# 6   young corn on the cob, honey, lemon juice, gar...
# 7   milk, rice (washed), sugar, raisins, green car...
# 8   turkey breast, cajun spice, spinach leaves (co...
# 9   whole turkey, butter, onion, celery, crumbled ...
# 10  brioche loaf, avocado paste, eggs, tomato, spi...
# 11  popped amaranth seeds, jaggery, almonds (slive...
# 12  apples, milk, sugar, green cardamoms, almonds ...
# 13  मक्खन, कैस्टर शुगर, क्रिसमस मिक्स स्पाइसी, दाल...
# 14  ragi flour, oats flour, dates (ripe), milk, ho...
# 15  puffed rice, nuts, honey, jaggery, butter, kew...
# 16  christmas dry fruits (pre-soaked), orange zest...
# 17  cashew paste, ghee, khaand (a sweetening agent...
# 18  prawns, gherkin, onion, cilantro, mix bell pep...
# 19  fresh corn kernels, corn flour, whole egg, che...
# 20                                                NaN
# 21  chicken drum sticks/ chicken breast, soy sauce...
# 22  fresh strawberries, honey, low fat yogurt, wat...
# 23  zucchini, basmati rice, fenugreek (methi), cla...
